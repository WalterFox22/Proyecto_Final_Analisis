# %%
import pandas as pd
from pymongo import MongoClient

# %%
# Conectar a la base de datos de MongoDB Atlas
uri = "mongodb+srv://Walter:Walyfox22@cluster0.p2y1kwu.mongodb.net/ANALISIS?retryWrites=true&w=majority&appName=Cluster0"
client = MongoClient(uri)

# Seleccionar la base de datos
db = client['ANALISIS']

# Seleccionar la colección
collection = db['Transito']

# Leer los documentos de la colección
data = list(collection.find())

# %%
# Cargar los datos en un DataFrame de Pandas
df = pd.DataFrame(data)

# %%
# Mostrar el DataFrame
df
# Out:
#                               _id  PROVINCIA      CANTÓN    MES     DIA  \
# 0        66b792feb049e88fc4521fb0     GUAYAS    NARANJAL  ENERO  SÁBADO
# 1        66b792feb049e88fc4521fb1     GUAYAS       DURAN  ENERO  SÁBADO
# 2        66b792feb049e88fc4521fb2  PICHINCHA       QUITO  ENERO  SÁBADO
# 3        66b792feb049e88fc4521fb3  PICHINCHA       QUITO  ENERO  SÁBADO
# 4        66b792feb049e88fc4521fb4   LOS RÍOS      VINCES  ENERO  SÁBADO
# ...                           ...        ...         ...    ...     ...
# 1860733  66b797bfb049e88fc46e842d     EL ORO  SANTA ROSA    NaN     NaN
# 1860734  66b797bfb049e88fc46e842e       LOJA      PALTAS    NaN     NaN
# 1860735  66b797bfb049e88fc46e842f     GUAYAS   GUAYAQUIL    NaN     NaN
# 1860736  66b797bfb049e88fc46e8430    BOLIVAR   ECHEANDÍA    NaN     NaN
# 1860737  66b797bfb049e88fc46e8431     EL ORO     MACHALA    NaN     NaN
#
#                   HORA    ZONA             CLASE  \
# 0        00:00 A 00:59   RURAL           CHOQUES
# ...

# %%
# Filtrar las filas donde las columnas específicas no tienen valores nulos
columnas_filtrar = ['_id', 'PROVINCIA', 'CANTÓN', 'MES', 'DIA', 'HORA', 'ZONA', 'CLASE', 'CAUSA', 'NUM_FALLECIDO', 'NUM_LESIONADO', 'TOTAL_VICTIMAS']
df_filtrado = df.dropna(subset=columnas_filtrar)

# %%
# Seleccionar solo las columnas que deseas mostrar
columnas_deseadas = ['_id', 'PROVINCIA', 'CANTÓN', 'MES', 'DIA', 'HORA', 'ZONA', 'CLASE', 'CAUSA', 'NUM_FALLECIDO', 'NUM_LESIONADO', 'TOTAL_VICTIMAS']
df_filtrado = df_filtrado[columnas_deseadas]

# %%
# Mostrar el DataFrame filtrado con solo las columnas deseadas
df_filtrado
# Out:
#                             _id  PROVINCIA     CANTÓN        MES     DIA  \
# 0      66b792feb049e88fc4521fb0     GUAYAS   NARANJAL      ENERO  SÁBADO
# 1      66b792feb049e88fc4521fb1     GUAYAS      DURAN      ENERO  SÁBADO
# 2      66b792feb049e88fc4521fb2  PICHINCHA      QUITO      ENERO  SÁBADO
# 3      66b792feb049e88fc4521fb3  PICHINCHA      QUITO      ENERO  SÁBADO
# 4      66b792feb049e88fc4521fb4   LOS RÍOS     VINCES      ENERO  SÁBADO
# ...                         ...        ...        ...        ...     ...
# 21734  66b7930cb049e88fc4527496     GUAYAS  GUAYAQUIL  DICIEMBRE  SÁBADO
# 21735  66b7930cb049e88fc4527497     GUAYAS  GUAYAQUIL  DICIEMBRE  SÁBADO
# 21736  66b7930cb049e88fc4527498     GUAYAS  GUAYAQUIL  DICIEMBRE  SÁBADO
# 21737  66b7930cb049e88fc4527499     GUAYAS  GUAYAQUIL  DICIEMBRE  SÁBADO
# 21738  66b7930cb049e88fc452749a     GUAYAS  GUAYAQUIL  DICIEMBRE  SÁBADO
#
#                 HORA    ZONA             CLASE  \
# ...

# %%
# Guardar el DataFrame filtrado en un archivo CSV con el nombre deseado
df_filtrado.to_csv('transito_filtrado_exportacion.csv', index=False)

# %%
# Crear una copia del DataFrame filtrado y convertir todos los datos a tipo string
df_filtrado_str = df_filtrado.astype(str)
# Guardar la copia del DataFrame filtrado en un archivo JSON con el nombre deseado
df_filtrado_str.to_json('transito_filtrado_exportacion.json', orient='records', lines=True, force_ascii=False)

# %%
import sqlite3
import pandas as pd

# %%
# Leer el archivo CSV en un DataFrame de Pandas
csv_file_path = r'C:\Users\Soledad Cobacango\Documents\Trabajos\Politecnica\TERCER SEMESTRE\ANALISIS DE DATOS\DATASETS\RESTAURANTES\Restaurant Business Rankings 2020\Top250.csv'
df_csv = pd.read_csv(csv_file_path)

# Crear o conectarse a la base de datos SQLite
sqlite_db_path = 'Proyecto_Final_Analisis.db'  # Nombre del archivo de la base de datos SQLite
sqlite_connection = sqlite3.connect(sqlite_db_path)

# Guardar el DataFrame en la base de datos SQLite
table_name = 'restaurant_rankings'  # Nombre de la tabla donde se guardarán los datos
df_csv.to_sql(table_name, sqlite_connection, if_exists='replace', index=False)

# Importar la tabla desde la base de datos SQLite a un DataFrame de Pandas
df_restaurant_rankings = pd.read_sql_query("SELECT * FROM restaurant_rankings", sqlite_connection)

# %%
df_restaurant_rankings
# Out:
#      Rank           Restaurant  \
# 0       1           McDonald's
# 1       2            Starbucks
# 2       3          Chick-fil-A
# 3       4            Taco Bell
# 4       5          Burger King
# ..    ...                  ...
# 245   246      Rainforest Cafe
# 246   247                  PDQ
# 247   248        Lupe Tortilla
# 248   249  Cook-Out Restaurant
# 249   250             Jollibee
#
#                                                Content  Sales YOY_Sales  \
# 0                                                 None  40412      4.9%
# 1                                                 None  21380      8.6%
# 2    While Popeyes got a lot of the chicken buzz in...  11320     13.0%
# 3                                                 None  11293      9.0%
# 4                                                 None  10204      2.7%
# ..                                                 ...    ...       ...
# 245                                               None    129    -10.4%
# ...

# %%
# Guardar el DataFrame en un archivo JSON con el nombre deseado
df_restaurant_rankings.to_json('datos_restaurantes_import.json', orient='records', lines=True, force_ascii=False)

# %%
sqlite_connection.close()

# %%
# Leer el archivo CSV en un DataFrame de Pandas
ruta_csv_independence = r'C:\Users\Soledad Cobacango\Documents\Trabajos\Politecnica\TERCER SEMESTRE\ANALISIS DE DATOS\DATASETS\RESTAURANTES\Restaurant Business Rankings 2020\Independence100.csv'
df_independence = pd.read_csv(ruta_csv_independence)

# Crear o conectarse a la base de datos SQLite
ruta_db_independence = 'Proyecto_Final_Analisis.2.db'  # Nombre del archivo de la base de datos SQLite
conexion_sqlite_independence = sqlite3.connect(ruta_db_independence)

# Guardar el DataFrame en la base de datos SQLite
nombre_tabla_independence = 'independence_rankings'  # Nombre de la tabla donde se guardarán los datos
df_independence.to_sql(nombre_tabla_independence, conexion_sqlite_independence, if_exists='replace', index=False)

# Importar la tabla desde la base de datos SQLite a un DataFrame de Pandas
df_independence_rankings = pd.read_sql_query(f"SELECT * FROM {nombre_tabla_independence}", conexion_sqlite_independence)

# %%
df_independence_rankings
# Out:
#     Rank                           Restaurant       Sales  Average Check  \
# 0      1             Carmine's (Times Square)  39080335.0             40
# 1      2                The Boathouse Orlando  35218364.0             43
# 2      3                     Old Ebbitt Grill  29104017.0             33
# 3      4  LAVO Italian Restaurant & Nightclub  26916180.0             90
# 4      5             Bryant Park Grill & Cafe  26900000.0             62
# ..   ...                                  ...         ...            ...
# 95    96                 George's at the Cove  12194000.0             80
# 96    97                            Le Coucou  12187523.0             95
# 97    98                              Mi Vida  12032014.0             38
# 98    99                               Upland  11965564.0             52
# 99   100               Virgil's Real Barbecue  11391678.0             27
#
#           City   State  Meals Served
# 0     New York    N.Y.      469803.0
# ...

# %%
# Guardar el DataFrame en un archivo JSON con el nombre deseado
df_independence_rankings.to_json('datos_independence_import.json', orient='records', lines=True, force_ascii=False)

# %%
# Cerrar la conexión a la base de datos
conexion_sqlite_independence.close()

# %%
import pandas as pd
from sqlalchemy import create_engine
import mysql.connector
from mysql.connector import Error
from IPython.display import display

# %%
# Leer el archivo CSV en un DataFrame de Pandas con la codificación ISO-8859-1
ruta_csv_mysql = r'C:\Users\Soledad Cobacango\Documents\Trabajos\Politecnica\TERCER SEMESTRE\ANALISIS DE DATOS\DATASETS\HOBBYS Y ACTIVIDADES\dance data.csv'
df_mysql = pd.read_csv(ruta_csv_mysql, encoding='ISO-8859-1')

# Conectar a MySQL
conexion_mysql = None
try:
    # Crear la base de datos si no existe
    conexion_mysql = mysql.connector.connect(
        host='localhost',
        user='root',
        password='123456'
    )

    if conexion_mysql.is_connected():
        print('Conexión a MySQL exitosa')

        # Crear la base de datos
        cursor = conexion_mysql.cursor()
        cursor.execute("CREATE DATABASE IF NOT EXISTS proyecto_final_mysql")
        cursor.execute("USE proyecto_final_mysql")  # Usar la base de datos recién creada

        # Crear el motor de SQLAlchemy
        engine = create_engine('mysql+mysqlconnector://root:123456@localhost/proyecto_final_mysql')

        # Guardar el DataFrame en la base de datos MySQL
        nombre_tabla_mysql = 'dance_data'  # Nombre de la tabla donde se guardarán los datos
        df_mysql.to_sql(nombre_tabla_mysql, con=engine, if_exists='replace', index=False)
        # Guardar el DataFrame en un archivo CSV
        df_imported_mysql.to_csv(r'C:\Users\Soledad Cobacango\Documents\Trabajos\Politecnica\TERCER SEMESTRE\ANALISIS DE DATOS\DATASETS\HOBBYS Y ACTIVIDADES\dance_data_from_mysql.csv', index=False)

        print('Datos guardados en dance_data_from_mysql.csv')

        # Mostrar la tabla importada
        df_imported_mysql = pd.read_sql_query(f"SELECT * FROM {nombre_tabla_mysql}", engine)
        display(df_imported_mysql)

except Error as e:
    print(f'Error al conectarse a MySQL: {e}')
# Out:
# Conexión a MySQL exitosa
# Datos guardados en dance_data_from_mysql.csv
#     Dance Type                      Dance style         Origin   Time Period  \
# 0     American                      fella shake  United States  Contemporary
# 1     American                      tap dancing  United States  20th century
# 2     American  fella fella fella Im 100% fella  United States        Modern
# 3     American                         Stepping  United States  20th century
# 4     American                             Jazz  United States  20th century
# ..         ...                              ...            ...           ...
# 201      Other                             KPop          Korea  Contemporary
# 202      Other                 Liturgical dance  United States  20th century
# 203      Other                    Lyrical dance  United States  20th century
# 204      Other                       Pole dance  United States  20th century
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
# no funciona por falta de credenciales solo es un ejemplo 
import pyodbc
from azure.identity import DefaultAzureCredential

# Configuración de la conexión
server = 'proyectoanalisis.database.windows.net'
database = 'Proyecto'
username = 'john.cobacango@epn.edu.ec'  # Tu correo electrónico
driver = '{ODBC Driver 17 for SQL Server}'

# Obtener token de acceso
credential = DefaultAzureCredential()
token = credential.get_token("https://database.windows.net//.default").token

# Crear la conexión usando el token de acceso
conn = pyodbc.connect(
    f'DRIVER={driver};SERVER={server};PORT=1433;DATABASE={database};UID={username};Authentication=ActiveDirectoryAccessToken;',
    attrs={"AccessToken": token}
)

cursor = conn.cursor()

# %%
import json

# Ruta al archivo JSON
file_path = r'C:\Temp\independence_rankings.json'

# Leer el archivo JSON
with open(file_path, 'r') as file:
    data = json.load(file)
# Crear la tabla si no existe
create_table_query = '''
CREATE TABLE independence_rankings (
    Rank VARCHAR(100) PRIMARY KEY,
    Restaurant VARCHAR(400),
    Sales INT,
    Average_Check INT,
    City VARCHAR(100),
    State VARCHAR(50),
    Meals_Served FLOAT
)
'''

cursor.execute(create_table_query)
conn.commit()

# %%
# Insertar datos en la tabla
for item in data:
    cursor.execute('''
    INSERT INTO independence_rankings (Rank, Restaurant, Sales, Average_Check, City, State, Meals_Served)
    VALUES (?, ?, ?, ?, ?, ?, ?)
    ''',
    item['Rank'], item['Restaurant'], item['Sales'], item['Average_Check'], item['City'], item['State'], item['Meals_Served'])

conn.commit()

# %%
# Consultar la tabla para verificar los datos
cursor.execute('SELECT * FROM independence_rankings')
rows = cursor.fetchall()

for row in rows:
    print(row)

# %%
## SEGUIR COMPLETANDO CON SUS PARTES

# %%
#Dataset Noticias

#Envio de datos a mysql
#importamos pandas y sqlalchemy para el envio de datos
import pandas as pd
from sqlalchemy import create_engine

#codigo para la conexion
ruta_archivo = 'C:/Users/darwi/OneDrive/Desktop/proyecto analisis/data/Noticias'
usuario = 'root'
password = ''
host = 'localhost'
base_de_datos = 'noticias'

engine = create_engine(f'mysql+pymysql://{usuario}:{password}@{host}/{base_de_datos}')

# %%
#cargamos los datos al dataframe
df = pd.read_csv(f'{ruta_archivo}/UkraineConflict.csv')
df
# Out:
#       EVENT_ID_CNTY      EVENT_DATE  YEAR  TIME_PRECISION  \
# 0            ROU448     20-May-2019  2019               1
# 1           ROU1885   28-March-2022  2022               1
# 2           ROU1940    28-July-2022  2022               1
# 3           ROU1945    31-July-2022  2022               1
# 4           ROU1947  04-August-2022  2022               1
# ...             ...             ...   ...             ...
# 96077      UKR96344   17-March-2023  2023               1
# 96078      UKR96345   17-March-2023  2023               1
# 96079      UKR96346   17-March-2023  2023               1
# 96080      UKR96347   17-March-2023  2023               1
# 96081      UKR96375   17-March-2023  2023               1
#
#                 DISORDER_TYPE                  EVENT_TYPE  \
# 0          Political violence  Violence against civilians
# 1      Strategic developments      Strategic developments
# 2              Demonstrations                    Protests
# ...

# %%
# Ver los tipos de datos de las columnas
df.dtypes

# Contar la cantidad de valores nulos por columna
df.isnull().sum()
# Out:
# EVENT_ID_CNTY             0
# EVENT_DATE                0
# YEAR                      0
# TIME_PRECISION            0
# DISORDER_TYPE             0
# EVENT_TYPE                0
# SUB_EVENT_TYPE            0
# ACTOR1                    0
# ASSOC_ACTOR_1         89594
# INTER1                    0
# ACTOR2                44253
# ASSOC_ACTOR_2         81404
# INTER2                    0
# INTERACTION               0
# CIVILIAN_TARGETING    91894
# ISO                       0
# REGION                    0
# COUNTRY                   0
# ADMIN1                   17
# ADMIN2                   91
# ADMIN3                 2402
# LOCATION                  0
# LATITUDE                  0
# LONGITUDE                 0
# GEO_PRECISION             0
# SOURCE                    0
# SOURCE_SCALE              0
# NOTES                     0
# FATALITIES                0
# TAGS                  90144
# TIMESTAMP                 0
# dtype: int64

# %%
#Cambiamos datos nulos
df = df.fillna(0)
df.isnull().sum()
# Out:
# EVENT_ID_CNTY         0
# EVENT_DATE            0
# YEAR                  0
# TIME_PRECISION        0
# DISORDER_TYPE         0
# EVENT_TYPE            0
# SUB_EVENT_TYPE        0
# ACTOR1                0
# ASSOC_ACTOR_1         0
# INTER1                0
# ACTOR2                0
# ASSOC_ACTOR_2         0
# INTER2                0
# INTERACTION           0
# CIVILIAN_TARGETING    0
# ISO                   0
# REGION                0
# COUNTRY               0
# ADMIN1                0
# ADMIN2                0
# ADMIN3                0
# LOCATION              0
# LATITUDE              0
# LONGITUDE             0
# GEO_PRECISION         0
# SOURCE                0
# SOURCE_SCALE          0
# NOTES                 0
# FATALITIES            0
# TAGS                  0
# TIMESTAMP             0
# dtype: int64

# %%
#Borramos las columnas que no necesitamos
columnas_a_eliminar = ['TIME_PRECISION','ADMIN1','ADMIN2','ADMIN3','TIMESTAMP']
df =  df.drop(columns= columnas_a_eliminar)
df
# Out:
#       EVENT_ID_CNTY      EVENT_DATE  YEAR           DISORDER_TYPE  \
# 0            ROU448     20-May-2019  2019      Political violence
# 1           ROU1885   28-March-2022  2022  Strategic developments
# 2           ROU1940    28-July-2022  2022          Demonstrations
# 3           ROU1945    31-July-2022  2022  Strategic developments
# 4           ROU1947  04-August-2022  2022          Demonstrations
# ...             ...             ...   ...                     ...
# 96077      UKR96344   17-March-2023  2023      Political violence
# 96078      UKR96345   17-March-2023  2023      Political violence
# 96079      UKR96346   17-March-2023  2023      Political violence
# 96080      UKR96347   17-March-2023  2023      Political violence
# 96081      UKR96375   17-March-2023  2023      Political violence
#
#                        EVENT_TYPE                     SUB_EVENT_TYPE  \
# 0      Violence against civilians                             Attack
# ...

# %%
#subimos los datos limpios a la base de datos en mysql
#y en este paso los transformamos al tipo de dato que admite la base de datos
df.to_sql('proyecto_noticias_1', con=engine, if_exists='replace', index=False)
print('Datos subidos exitosamente')
# Out:
# Datos subidos exitosamente

# %%
#exportar datos de la base

consulta = 'SELECT * FROM proyecto_noticias_1'
df_aux = pd.read_sql(consulta, engine)
ruta_archivo = 'C:/Users/darwi/OneDrive/Desktop/proyecto analisis/data/dataExportada'

#transformamos de .sql a .csv y almacenamos los datos en la ruta indicada
df_aux.to_csv(f'{ruta_archivo}/exportado_noticias_1.csv', index=False)

# %%
#----------------Conexion a sql lite
ruta_archivo = 'C:/Users/darwi/OneDrive/Desktop/proyecto analisis/data/'
engine =  create_engine(f'sqlite:///{ruta_archivo}not.db')

# %%
#cargamos los datos al dataframe
df = pd.read_csv(f'{ruta_archivo}Noticias/covid19_usa_hospital.csv')
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #cargamos los datos al dataframe
# ----> 2 df = pd.read_csv(f'{ruta_archivo}Noticias/covid19_usa_hospital.csv')
#       3 df
#
# NameError: name 'pd' is not defined

# %%
df.dtypes

df.isnull().sum()

#guardamos los datos en sqlite
df.to_sql('proyecto_noticias_2', engine, if_exists='replace',index=False)
# Out:
# 5713

# %%
#verificamos la inserccion si lo queremos
df_consulta = pd.read_sql('SELECT * FROM proyecto_noticias_2', engine)
df_consulta
# Out:
#      country state          county        lat         lng         type  \
# 0         US    AK  aleutians east  63.588753 -154.493062          ICU
# 1         US    AK  aleutians west  63.588753 -154.493062          ICU
# 2         US    AK       anchorage  63.588753 -154.493062        ACUTE
# 3         US    AK       anchorage  63.588753 -154.493062          ICU
# 4         US    AK       anchorage  63.588753 -154.493062        OTHER
# ...      ...   ...             ...        ...         ...          ...
# 5708      US    WY           uinta  43.075968 -107.290284        ACUTE
# 5709      US    WY           uinta  43.075968 -107.290284          ICU
# 5710      US    WY           uinta  43.075968 -107.290284  PSYCHIATRIC
# 5711      US    WY        washakie  43.075968 -107.290284          ICU
# 5712      US    WY          weston  43.075968 -107.290284          ICU
#
#       measure      beds  population  year  source  \
# 0     1000HAB  0.000000        3338  2019     khn
# ...

# %%
consulta = 'SELECT * FROM proyecto_noticias_2'
df_aux = pd.read_sql(consulta, engine)
ruta_archivo = 'C:/Users/darwi/OneDrive/Desktop/proyecto analisis/data/dataExportada'

#transformamos de .sql a .csv y almacenamos los datos en la ruta indicada
df_aux.to_csv(f'{ruta_archivo}/exportado_noticias_2.csv', index=False)

# %%
#-----------------Restaurantes y sitios
#Conexion con mongoDb local
from pymongo import MongoClient

client =  MongoClient('mongodb://localhost:27017/')
                      
db = client['proyecto_restau_sitio']
coleccion1 = db['restaurantes']
coleccion2 = db['sitios_espar']

# %%
#cargamos los datos al dataframe
ruta_archivo = 'C:/Users/darwi/OneDrive/Desktop/proyecto analisis/data/'
df_restaurant = pd.read_csv(f'{ruta_archivo}Restaurante y sitios/zomato.csv')
df_restaurant
# Out:
#       Unnamed: 0.1  Unnamed: 0         restaurant name     restaurant type  \
# 0                0           0            #FeelTheROLL         Quick Bites
# 1                1           1              #L-81 Cafe         Quick Bites
# 2                2           2                 #refuel                Cafe
# 3                3           3      '@ Biryani Central       Casual Dining
# 4                4           4              '@ The Bbq       Casual Dining
# ...            ...         ...                     ...                 ...
# 7100          7100        7100                  Zoey's                Cafe
# 7101          7101        7101  ZOROY Luxury Chocolate      Dessert Parlor
# 7102          7102        7102       Zu's Doner Kebaps  Takeaway, Delivery
# 7103          7103        7103                   Zyara       Casual Dining
# 7104          7104        7104                  Zyksha          Food Truck
#
# ...

# %%
df_restaurant.dtypes

df_restaurant.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df_restaurant.dtypes
#       3 df_restaurant.isnull().sum()
#
# NameError: name 'df_restaurant' is not defined

# %%
#Cambiamos datos nulos
df_restaurant = df_restaurant.fillna(0)
df_restaurant.isnull().sum()
# Out:
# Unnamed: 0.1             0
# Unnamed: 0               0
# restaurant name          0
# restaurant type          0
# rate (out of 5)          0
# num of ratings           0
# avg cost (two people)    0
# online_order             0
# table booking            0
# cuisines type            0
# area                     0
# local address            0
# dtype: int64

# %%
#Borramos las columnas que no necesitamos
columnas_a_eliminar = ['Unnamed: 0.1','Unnamed: 0']
df_restaurant =  df_restaurant.drop(columns= columnas_a_eliminar)
df_restaurant
# Out:
#              restaurant name     restaurant type  rate (out of 5)  \
# 0               #FeelTheROLL         Quick Bites              3.4
# 1                 #L-81 Cafe         Quick Bites              3.9
# 2                    #refuel                Cafe              3.7
# 3         '@ Biryani Central       Casual Dining              2.7
# 4                 '@ The Bbq       Casual Dining              2.8
# ...                      ...                 ...              ...
# 7100                  Zoey's                Cafe              4.3
# 7101  ZOROY Luxury Chocolate      Dessert Parlor              4.0
# 7102       Zu's Doner Kebaps  Takeaway, Delivery              3.7
# 7103                   Zyara       Casual Dining              3.8
# 7104                  Zyksha          Food Truck              3.4
#
#       num of ratings  avg cost (two people) online_order table booking  \
# 0                  7                  200.0           No            No
# ...

# %%
#quitamos caracteres especiales
df_restaurant['restaurant name'] = df_restaurant['restaurant name'].str.replace(r'[^a-zA-Z0-9\s]','',regex=True) 
df_restaurant
# Out:
#              restaurant name     restaurant type  rate (out of 5)  \
# 0                FeelTheROLL         Quick Bites              3.4
# 1                   L81 Cafe         Quick Bites              3.9
# 2                     refuel                Cafe              3.7
# 3            Biryani Central       Casual Dining              2.7
# 4                    The Bbq       Casual Dining              2.8
# ...                      ...                 ...              ...
# 7100                   Zoeys                Cafe              4.3
# 7101  ZOROY Luxury Chocolate      Dessert Parlor              4.0
# 7102        Zus Doner Kebaps  Takeaway, Delivery              3.7
# 7103                   Zyara       Casual Dining              3.8
# 7104                  Zyksha          Food Truck              3.4
#
#       num of ratings  avg cost (two people) online_order table booking  \
# 0                  7                  200.0           No            No
# ...

# %%
#datos insertados en mongo
datos_rest = df_restaurant.to_dict(orient='records')
coleccion1.insert_many(datos_rest)
# Out:
# InsertManyResult([ObjectId('66b933ab51af29acd621fcbb'), ObjectId('66b933ab51af29acd621fcbc'), ObjectId('66b933ab51af29acd621fcbd'), ObjectId('66b933ab51af29acd621fcbe'), ObjectId('66b933ab51af29acd621fcbf'), ObjectId('66b933ab51af29acd621fcc0'), ObjectId('66b933ab51af29acd621fcc1'), ObjectId('66b933ab51af29acd621fcc2'), ObjectId('66b933ab51af29acd621fcc3'), ObjectId('66b933ab51af29acd621fcc4'), ObjectId('66b933ab51af29acd621fcc5'), ObjectId('66b933ab51af29acd621fcc6'), ObjectId('66b933ab51af29acd621fcc7'), ObjectId('66b933ab51af29acd621fcc8'), ObjectId('66b933ab51af29acd621fcc9'), ObjectId('66b933ab51af29acd621fcca'), ObjectId('66b933ab51af29acd621fccb'), ObjectId('66b933ab51af29acd621fccc'), ObjectId('66b933ab51af29acd621fccd'), ObjectId('66b933ab51af29acd621fcce'), ObjectId('66b933ab51af29acd621fccf'), ObjectId('66b933ab51af29acd621fcd0'), ObjectId('66b933ab51af29acd621fcd1'), ObjectId('66b933ab51af29acd621fcd2'), ObjectId('66b933ab51af29acd621fcd3'), ObjectId('66b933ab51af29acd621
# ...

# %%
#archivo de sitios tambien en mongo
df_sitios = pd.read_csv(f'{ruta_archivo}Restaurante y sitios/travel.csv')
df_sitios
# Out:
#       Agency    Agency Type Distribution Channel  \
# 0        CBH  Travel Agency              Offline
# 1        CBH  Travel Agency              Offline
# 2        CWT  Travel Agency               Online
# 3        CWT  Travel Agency               Online
# 4        CWT  Travel Agency               Online
# ...      ...            ...                  ...
# 63321    JZI       Airlines               Online
# 63322    JZI       Airlines               Online
# 63323    JZI       Airlines               Online
# 63324    JZI       Airlines               Online
# 63325    JZI       Airlines               Online
#
#                           Product Name Claim  Duration Destination  Net Sales  \
# 0                   Comprehensive Plan    No       186    MALAYSIA      -29.0
# 1                   Comprehensive Plan    No       186    MALAYSIA      -29.0
# 2      Rental Vehicle Excess Insurance    No        65   AUSTRALIA      -49.5
# ...

# %%
df_sitios.dtypes

df_sitios.isnull().sum()

columnas_a_eliminar = ['Gender']
df_sitios =  df_sitios.drop(columns= columnas_a_eliminar)

# %%
datos_sitios = df_sitios.to_dict(orient='records')
coleccion2.insert_many(datos_sitios)
# Out:
# InsertManyResult([ObjectId('66b935ba51af29acd622187c'), ObjectId('66b935ba51af29acd622187d'), ObjectId('66b935ba51af29acd622187e'), ObjectId('66b935ba51af29acd622187f'), ObjectId('66b935ba51af29acd6221880'), ObjectId('66b935ba51af29acd6221881'), ObjectId('66b935ba51af29acd6221882'), ObjectId('66b935ba51af29acd6221883'), ObjectId('66b935ba51af29acd6221884'), ObjectId('66b935ba51af29acd6221885'), ObjectId('66b935ba51af29acd6221886'), ObjectId('66b935ba51af29acd6221887'), ObjectId('66b935ba51af29acd6221888'), ObjectId('66b935ba51af29acd6221889'), ObjectId('66b935ba51af29acd622188a'), ObjectId('66b935ba51af29acd622188b'), ObjectId('66b935ba51af29acd622188c'), ObjectId('66b935ba51af29acd622188d'), ObjectId('66b935ba51af29acd622188e'), ObjectId('66b935ba51af29acd622188f'), ObjectId('66b935ba51af29acd6221890'), ObjectId('66b935ba51af29acd6221891'), ObjectId('66b935ba51af29acd6221892'), ObjectId('66b935ba51af29acd6221893'), ObjectId('66b935ba51af29acd6221894'), ObjectId('66b935ba51af29acd622
# ...

# %%
#Exportar los datos almacenados en mongo en archivos csv
curso1 = coleccion1.find()
cursor2 = coleccion2.find()

datos1 = list(curso1)
datos2 = list(cursor2)

df_rest = pd.DataFrame(datos1)
df_sit = pd.DataFrame(datos2)

df_rest.to_csv(f'{ruta_archivo}dataExportada/exportado_restaurantes.csv', index=False)
df_sit.to_csv(f'{ruta_archivo}dataExportada/exportado_sitios.csv', index=False)

# %% [markdown]
# ## Eventos deportivos

# %%
#Lectura de datasets mediante pandas 
import pandas as pd
df1 = pd.read_csv('olympic_cities.csv')
print(df1)

# %%
df2 = pd.read_csv("veriseti_20220203_olimpiyatlar.csv")
print(df2)

# %%
#Limpieza de datos duplicados

duplicados = df1.duplicated()
print(duplicados)

# %%
duplicados = df2.duplicated()
print(duplicados)

# %%
#Limpieza de datos nulos
nulos= df1.isnull()
print(nulos)

# %%
# Datos nulos
print(df2.isnull().sum())
print(df1.isnull().sum())

# %%
# Eliminar la columnas innecesarias
df2.drop(columns=['ID', 'NOC', 'Height', 'Weight'], inplace=True)
print(df2)

# %%
# Remplazo de valores nulos
df2['Medal'] = df2['Medal'].fillna("Ninguna")
print(df2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df2['Medal'] = df2['Medal'].fillna("Ninguna")
#       2 print(df2)
#
# NameError: name 'df2' is not defined

# %%
#Envio de datos a mongodb Compass

#Dataset1
from pymongo import MongoClient
client = MongoClient('mongodb://localhost:27017/') 
db = client['Eventos_deportivos']
collection = db['olimpiadas_cities']

data = df1.to_dict(orient='records')
# Insertar datos en MongoDB
collection.insert_many(data)
print("Datos insertados en MongoDB exitosamente.")

# %%
#Envio de datos a mongodb
#Dataset2
from pymongo import MongoClient
client = MongoClient('mongodb://localhost:27017/') 
db = client['Eventos_deportivos']
collection = db['olimpiadas']
data = df2.to_dict(orient='records')
# Insertar datos en MongoDB
collection.insert_many(data)
print("Datos insertados en MongoDB exitosamente.")

# %%
#IMPORTAR DATOS CON ATLAS
import pymongo
import pandas as pd

# %%
#Envio de datos a mongodb atlas

#Dataset1
client = pymongo.MongoClient("mongodb+srv://alisson01:1234567891@cluster0.zi0fx.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
db = client['Eventos_deportivos']
collection = db['olimpiadas']
data = df1.to_dict(orient='records')
collection.insert_many(data)

print("Datos importados exitosamente a MongoDB Atlas")

# %%
#Dataset2
client = pymongo.MongoClient("mongodb+srv://alisson01:1234567891@cluster0.zi0fx.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
db = client['Eventos_deportivos']
collection = db['olimpiadas']
data = df2.to_dict(orient='records')
collection.insert_many(data)

print("Datos importados exitosamente a MongoDB Atlas")

# %%
#Envio de datos a mysql
#Instalar las bibliotecas (pip install pandas sqlalchemy mysql-connector-python)
from sqlalchemy import create_engine

# %%
#Dataset1
usuario = 'root'
contraseña = '123456789'
host = 'localhost'  
base_de_datos = 'eventos_deportivos'

# Crear la cadena de conexión
cadena_conexion = f'mysql+mysqlconnector://root:123456789@localhost/eventos_deportivos'

# Crear el motor de conexión
engine = create_engine(cadena_conexion)
nombre_tabla = 'olimpiadas_cities'

# Enviar los datos a MySQL
df1.to_sql(nombre_tabla, con=engine, if_exists='append', index=False)

print("Datos importados exitosamente.")

# %%
#Dataset2
usuario = 'root'
contraseña = '123456789'
host = 'localhost'  
base_de_datos = 'eventos_deportivos'

# Crear la cadena de conexión
cadena_conexion = f'mysql+mysqlconnector://root:123456789@localhost/eventos_deportivos'

# Crear el motor de conexión
engine = create_engine(cadena_conexion)
nombre_tabla = 'olimpiadas'

# Enviar los datos a MySQL
df2.to_sql(nombre_tabla, con=engine, if_exists='append', index=False)

print("Datos importados exitosamente.")

# %%
#Exportación de datos

#MONGO DB

client = MongoClient('mongodb://localhost:27017/')
db = client['Eventos_deportivos']
collection = db['olimpiadas_cities']

# Recuperar todos los documentos de la colección
documents = list(collection.find({}))

# Convertir los documentos a un DataFrame de pandas
df = pd.DataFrame(documents)

# Eliminar la columna '_id' 
if '_id' in df.columns:
    df.drop(columns=['_id'], inplace=True)

directorio = 'Datos_exportados'
nombre_archivo = 'olimpiadascities_exportados.csv'

ruta_archivo = f'Datos_exportados/olimpiadascities_exportados.csv'

# Exportar el DataFrame a un archivo CSV en la carpeta especificada
df.to_csv(ruta_archivo, index=False)

# %%
#Exporte de datos desde mysql

import mysql.connector

# Configura la conexión a MySQL
config = {
    'user': 'root',
    'password': '123456789',
    'host': 'localhost',
    'database': 'eventos_deportivos',
    'raise_on_warnings': True
}

# Conectar a MySQL
conn = mysql.connector.connect(**config)

# Definir la consulta SQL para seleccionar datos
query = "SELECT * FROM olimpiadas"

# Leer datos de la base de datos en un DataFrame de pandas
df = pd.read_sql(query, conn)

# Cerrar la conexión
conn.close()

directorio = 'Datos_exportados'
nombre_archivo = 'olimpiadas_exportadas.csv'

# Construir la ruta completa del archivo
ruta_archivo = f'Datos_exportados/olimpiadas_exportadas.csv'

# Exportar el DataFrame a un archivo CSV en la carpeta especificada
df.to_csv(ruta_archivo, index=False)

print(f"Datos exportados a '{ruta_archivo}'")
